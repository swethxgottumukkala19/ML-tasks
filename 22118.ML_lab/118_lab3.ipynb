# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Load the dataset into a DataFrame
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, header=None, names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'])
# Out:
# C:\Users\CSE-Lab1\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#2D SCATTERPLOT
sns.scatterplot(x='sepal_length', y='sepal_width', data=df, hue='species')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %%
# 3D Scatter Plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['sepal_length'], df['sepal_width'], df['petal_length'], c='r', marker='o')
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')
ax.set_title('3D Scatter Plot of Sepal and Petal Dimensions')
plt.show()
# Out:
# C:\Users\CSE-Lab1\AppData\Local\Temp\ipykernel_12120\1114076157.py:4: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.scatter(df['sepal_length'], df['sepal_width'], df['petal_length'], c='r', marker='o')

# %%
# 3D Scatter Plot with Color Encoding
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
species_colors = {'Iris-setosa': 'r', 'Iris-versicolor': 'g', 'Iris-virginica': 'b'}
ax.scatter(df['sepal_length'], df['sepal_width'], df['petal_length'], c=df['species'].map(species_colors), marker='o')
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')
ax.set_title('3D Scatter Plot of Sepal and Petal Dimensions with Species Color Encoding')
plt.show()
# Out:
# C:\Users\CSE-Lab1\AppData\Local\Temp\ipykernel_12120\3458509528.py:5: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.scatter(df['sepal_length'], df['sepal_width'], df['petal_length'], c=df['species'].map(species_colors), marker='o')

# %%
# 3D Line Plot, Plotting a line in 3D space, useful for visualizing trends or trajectories.
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot(df['sepal_length'], df['sepal_width'], df['petal_length'])
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')
ax.set_title('3D Line Plot of Sepal and Petal Dimensions')
plt.show()
# Out:
# C:\Users\CSE-Lab1\AppData\Local\Temp\ipykernel_12120\2283970268.py:4: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.plot(df['sepal_length'], df['sepal_width'], df['petal_length'])

# %%
# 3D Surface Plot (Example of a function of two variables), helpful for visualizing functions of two variables
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
x, y = np.meshgrid(x, y)
z = np.sin(x) + np.cos(y)
ax.plot_surface(x, y, z, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot of a Function')
plt.show()
# Out:
# C:\Users\CSE-Lab1\AppData\Local\Temp\ipykernel_12120\2580722461.py:8: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.plot_surface(x, y, z, cmap='viridis')

# %%
# Pair Plot
sns.pairplot(df, hue='species')
plt.title('Pair Plot')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Histogram
df.hist()
plt.suptitle('Histograms of Features')
plt.show()

# %%
# 3D Histogram to visualize the distribution of three variables simultaneously
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(df['sepal_length'], df['sepal_width'], bins=20)
xpos, ypos = np.meshgrid(xedges[:-1], yedges[:-1], indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0
dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Frequency')
ax.set_title('3D Histogram of Sepal Dimensions')
plt.show()
# Out:
# C:\Users\CSE-Lab1\AppData\Local\Temp\ipykernel_12120\1625991494.py:11: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

# %%
# 3D Bar Plot (Example with randomly generated data)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
x = np.arange(len(df['species'].unique())) # Numeric values for x-axis categories
y = np.arange(len(df['species'].unique())) # Numeric values for y-axis categories
x, y = np.meshgrid(x, y)
z = np.random.rand(len(df['species'].unique()), len(df['species'].unique()))
ax.bar3d(x.ravel(), y.ravel(), np.zeros_like(z).ravel(), 1, 1, z.ravel())
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Bar Plot')
plt.show()
# Out:
# C:\Users\CSE-Lab1\AppData\Local\Temp\ipykernel_12120\2452622332.py:8: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.bar3d(x.ravel(), y.ravel(), np.zeros_like(z).ravel(), 1, 1, z.ravel())

# %%
# Kernel Density Estimation (KDE) Plot
sns.kdeplot(data=df)
plt.title('Kernel Density Estimation (KDE) Plot')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Contour Plot
sns.kdeplot(x='sepal_length', y='sepal_width', data=df, fill=True)
plt.title('Contour Plot of Sepal Length vs Sepal Width')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Violin Plot
sns.violinplot(x='species', y='petal_length', data=df)
plt.title('Violin Plot of Petal Length by Species')
plt.show()

# %%
# Joint Plot
sns.jointplot(x='petal_length', y='petal_width', data=df, kind='reg')
plt.title('Joint Plot of Petal Length vs Petal Width')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Radviz Plot
from pandas.plotting import radviz
radviz(df, 'species')
plt.title('Radviz Plot')
plt.show()

# %%
# Box Plot
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Box Plot of Sepal Length by Species')
plt.show()

# %%
# HEATMAP
# Drop the non-numeric 'species' column
numeric_df = df.drop('species', axis=1)
# Compute correlations and plot heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap (Numeric Data Only)')
plt.show()

# %%
# noise removal by binning
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate Synthetic Data
np.random.seed(0)
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(scale=0.2, size=len(x))

# Step 2: Apply Binning
def binning(x, y, num_bins):
    bins = np.linspace(min(x), max(x), num_bins + 1)
    binned_x = np.digitize(x, bins)
    binned_y = [np.mean(y[binned_x == i]) for i in range(1, len(bins))]
    return np.array(binned_x), np.array(binned_y)

num_bins = 20
binned_x, binned_y = binning(x, y, num_bins)

# %%
# 1)fig = plt.figure(figsize=(10, 8)) - Initialize a new figure with a specific size.
# 2)ax = fig.add_subplot(111, projection='3d') - Add a 3D subplot to the figure.
# 3)x = np.linspace(0, 10, 100)- Create an array of 100 equally spaced points between 0 and 10.
# 4)z = np.sin(x) + np.cos(y)- Calculate the value of z using a mathematical function involving the x variable.
# 5)ax.plot_surface(x, y, z, cmap='viridis')- Plot a 3D surface using the x, y, and z data, with the 'viridis' colormap.
# 6)ax.set_xlabel('X') - Set the label for the x-axis.
# 7)ax = fig.add_subplot(111, projection='3d') - Add another 3D subplot to the same figure.
# 8)x = np.arange(len(df['species'].unique()))- Create an array of numerical values representing unique categories from a DataFrame col
# 9)x, y = np.meshgrid(x, y) - Create 2D arrays representing x and y coordinates for a 3D plot.
# 10)ax.bar3d(x.ravel(), y.ravel(), np.zeros_like(z).ravel(), 1, 1, z.ravel()) - Plot a 3D bar chart with given x, y, and z data, each 
# 11)hist, xedges, yedges = np.histogram2d(df['sepal_length'], df['sepal_width'], bins=20)- Compute a 2D histogram of two variables wit
# 12)xpos, ypos = np.meshgrid(xedges[:-1], yedges[:-1], indexing="ij")- Create meshgrid arrays for x and y coordinates based on histogr
# 13)xpos = xpos.ravel()-Flatten the meshgrid arrays for x positions to create a 1D array
import numpy as np
import matplotlib.pyplot as plt

# 1) Initialize a new figure with a specific size
fig = plt.figure(figsize=(10, 8))

# 2) Add a 3D subplot to the figure
ax = fig.add_subplot(111, projection='3d')

# 3) Create an array of 100 equally spaced points between 0 and 10
x = np.linspace(0, 10, 100)

# 4) Calculate the value of z using a mathematical function involving the x variable
z = np.sin(x)

# 5) Plot a 3D surface using the x, y, and z data, with the 'viridis' colormap
# (Note: y is not defined, so only x and z are used)
ax.plot_surface(x, np.zeros_like(x), z, cmap='viridis')

# 6) Set the label for the x-axis
ax.set_xlabel('X')

# 7) Add another 3D subplot to the same figure
ax = fig.add_subplot(111, projection='3d')

# 8) Create an array of numerical values representing unique categories from a DataFrame column
# (Note: df and y are not defined, so only x is used)
x = np.arange(10)  # Assuming there are 10 unique categories

# 9) Create 2D arrays representing x and y coordinates for a 3D plot
x, y = np.meshgrid(x, np.zeros_like(x))

# 10) Plot a 3D bar chart with given x, y, and z data
ax.bar3d(x.ravel(), y.ravel(), np.zeros_like(z).ravel(), 1, 1, z.ravel())

# 11) Compute a 2D histogram of two variables from a DataFrame
# (Note: df is not defined, so we'll use randomly generated data)
df = pd.DataFrame({'sepal_length': np.random.rand(100), 'sepal_width': np.random.rand(100)})
hist, xedges, yedges = np.histogram2d(df['sepal_length'], df['sepal_width'], bins=20)

# 12) Create meshgrid arrays for x and y coordinates based on histogram edges
xpos, ypos = np.meshgrid(xedges[:-1], yedges[:-1], indexing="ij")

# 13) Flatten the meshgrid arrays for x positions to create a 1D array
xpos = xpos.ravel()

# Show the plot
plt.show()
