# %%
import pandas as pd
path= "C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv"
data= pd.read_csv(path)

dimensions = data.shape
rows, cols = dimensions

print("Number of rows:", rows)
print("Number of columns:", cols)
# Out:
# C:\Users\CSE-Lab1\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Number of rows: 234
# Number of columns: 17

# %%
import pandas as pd
path= "C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv"
data= pd.read_csv(path)
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              234 non-null    int64
#  1   cca3              234 non-null    object
#  2   country           234 non-null    object
#  3   continent         234 non-null    object
#  4   2023 population   234 non-null    int64
#  5   2022 population   234 non-null    int64
#  6   2020 population   234 non-null    int64
#  7   2015 population   234 non-null    int64
#  8   2010 population   234 non-null    int64
#  9   2000 population   234 non-null    int64
#  10  1990 population   234 non-null    int64
#  11  1980 population   234 non-null    int64
#  12  1970 population   234 non-null    int64
#  13  area (km²)        234 non-null    float64
#  14  density (km²)     234 non-null    int64
#  15  growth rate       234 non-null    object
# ...

# %%
import pandas as pd
path= "C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv"
data= pd.read_csv(path)
# for col in data:
#     print(col)
# for row in data.iterrows():
#     print(row)
row3 = pd.read_csv(path, skiprows = lambda x: x!=3)
print(row3)
# Out:
# Empty DataFrame
# Columns: [3, USA, United States, North America, 339996563, 338289857, 335942003, 324607776, 311182845, 282398554, 248083732, 223140018, 200328340, 9372610, 37, 0.50%, 4.25%]
# Index: []

# %%
import pandas as pd
path= "C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv"
data= pd.read_csv(path)
print(data.dtypes)
# Out:
# rank                  int64
# cca3                 object
# country              object
# continent            object
# 2023 population       int64
# 2022 population       int64
# 2020 population       int64
# 2015 population       int64
# 2010 population       int64
# 2000 population       int64
# 1990 population       int64
# 1980 population       int64
# 1970 population       int64
# area (km²)          float64
# density (km²)         int64
# growth rate          object
# world percentage     object
# dtype: object

# %%
import pandas as pd
path= "C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv"
data= pd.read_csv(path)
print(data['rank'].max)
print(data.describe())
# Out:
# <bound method Series.max of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 229    230
# 230    231
# 231    232
# 232    233
# 233    234
# Name: rank, Length: 234, dtype: int64>
#              rank  2023 population  2022 population  2020 population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.437442e+07     3.407441e+07     3.350107e+07
# std     67.694165     1.373864e+08     1.367664e+08     1.355899e+08
# min      1.000000     5.180000e+02     5.100000e+02     5.200000e+02
# 25%     59.250000     4.225982e+05     4.197385e+05     4.152845e+05
# 50%    117.500000     5.643895e+06     5.559944e+06     5.493074e+06
# 75%    175.750000     2.324537e+07     2.247650e+07     2.144798e+07
# max    234.000000     1.428628e+09     1.425887e+09     1.424930e+09
#
#        2015 population  2010 population  2000 population  1990 population  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt 
path= "C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv"
data= pd.read_csv(path)
# x = [] 
# y = [] 
# for row in data: 
#     x.append(row[2]) 
#     y.append(row[0]) 

# plt.bar(x, y, color = 'g', label = "Rank") 
# plt.xlabel('country') 
# plt.ylabel('rank') 
# plt.title('rankings for different countries') 
# plt.legend() 
# plt.show() 
data['2023 population'].hist()
plt.title('2023 population')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Reading the dataset
df = pd.read_csv("C:\\Users\\CSE-Lab1\\Downloads\\world_population_data (1).csv")

# Dimensions of the dataset
print("Dimensions:", df.shape)

# Row and column names
print("Column names:", df.columns)
print("Row names:", df.index)

# Displaying data types of features
print("Data types:", df.dtypes)

# Computing statistics
print("Summary statistics:\n", df.describe())

# Visualization
sns.histplot(df['2023 population'])
plt.show()

sns.boxplot(x='2023 population', data=df)
plt.show()

sns.scatterplot(x='2023 population', y='rank', data=df)
plt.show()

sns.countplot(x='continent', data=df)
plt.show()

# Data type conversions
df['rank'] = df['rank'].astype('int')

# # Filling missing values
# df[''].fillna(df[''].mean(), inplace=True)

# # Removing features with missing values
# df.dropna(axis=1, inplace=True)

# # Unique values of a feature
# print("Unique values of feature:", df[''].unique())

# Applying filters on features
filtered_data = df[df['rank'] > 10]
filtered_data

print("Specific Row:")
print(df.iloc[0]) 


print("\nSpecific Column:")
print(df['cca3'])
# Out:
# Dimensions: (234, 17)
# Column names: Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')
# Row names: RangeIndex(start=0, stop=234, step=1)
# Data types: rank                  int64
# cca3                 object
# country              object
# continent            object
# 2023 population       int64
# 2022 population       int64
# 2020 population       int64
# 2015 population       int64
# 2010 population       int64
# 2000 population       int64
# 1990 population       int64
# 1980 population       int64
# 1970 population       int64
# area (km²)          float64
# density (km²)         int64
# growth rate          object
# world percentage     object
# dtype: object
# Summary statistics:
# ...
